# %% [markdown]
# Throughout this lesson, you've been trying different models on the same two datasets, wine and diabetes. Now, we're going to try our hand at accelerating this methodology by using AutoGluon. In this exercise, train two different AutonGluon models and see how they compare to previous iterations in exercise 1 and 2.
#
# You're tasked with completing the following steps:
# 1. Load in the wine dataset from scikit learn.
# 2. For the wine dataset, create a train and test split, 80% train / 20% test.
# 3. Create a AutoGluon Classifier model with these hyper parameters:
#     1. time_limit: 120
#     2. presets: best_quality
# 4. Output the model table summary
# 5. Evaluate the trained model on the test dataset
# 6. Load the diabetes dataset from scikit learn
# 7. For the Diabetes dataset, create a train and test split, 80% train / 20% test.
# 8. Create a AutoGluon Regression model with these hyper parameters:
#     1. eval_metric: r2
#     2. time_limit: 120
#     3. presets: best_quality
# 9. Output the model table summary
# 10. Evaluate the trained model on the test dataset

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Open up Sagemaker Studio

# %% [markdown]
# 1. Notebook should be using a `ml.t3.medium` instance (2 vCPU + 4 GiB)
# 2. Notebook should be using kernal: `Python 3 (MXNet 1.8 Python 3.7 CPU Optimized)`

# %%
# !pip install pip
# Out:
# Requirement already satisfied: pip in c:\users\hp\anaconda3\lib\site-packages (22.2.2)

# %%
# !pip install setuptools wheel
# Out:
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (69.5.1)
# Requirement already satisfied: wheel in c:\users\hp\anaconda3\lib\site-packages (0.43.0)

# %%
# !pip install "mxnet<2.0.0" bokeh==2.0.1
# Out:
# Collecting mxnet<2.0.0
#   Using cached mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Collecting bokeh==2.0.1
#   Using cached bokeh-2.0.1-py3-none-any.whl
# Requirement already satisfied: numpy>=1.11.3 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (1.24.3)
# Requirement already satisfied: pillow>=4.0 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (2.8.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (6.0)
# Requirement already satisfied: tornado>=5 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (6.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (4.3.0)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from bokeh==2.0.1) (2.11.3)
# Collecting numpy>=1.11.3
#   Using cached numpy-1.16.6.zip (5.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<2.19.0,>=2.18.4 in c:\users\hp\anaconda3\lib\site-packages (from mxnet<2.0.0) (2.18.4)
# Collecting graphviz<0.9.0,>=0.8.1
#   Using cached graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\anaconda3\lib\site-packages (from Jinja2>=2.7->bokeh==2.0.1) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from packaging>=16.8->bokeh==2.0.1) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.1->bokeh==2.0.1) (1.16.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\hp\anaconda3\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (2023.7.22)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (2.6)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py): started
#   Building wheel for numpy (setup.py): finished with status 'error'
#   Running setup.py clean for numpy
# Failed to build numpy
# Installing collected packages: numpy, graphviz, mxnet, bokeh
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Running setup.py install for numpy: started
#   Running setup.py install for numpy: finished with status 'error'
#   Rolling back uninstall of numpy
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy-1.24.3.dist-info\
#    from C:\Users\HP\anaconda3\Lib\site-packages\~umpy-1.24.3.dist-info
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\.libs\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~libs
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\__config__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\__config__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\__init__.cython-30.pxd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\__init__.pxd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\__init__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\__init__.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\__pycache__\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~_pycache__
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\_distributor_init.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\_globals.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\_globals.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\_pyinstaller\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~pyinstaller
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\_pytesttester.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\_pytesttester.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\_pytesttester.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\_typing\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~typing
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\_version.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\_version.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\array_api\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~rray_api
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\compat\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~ompat
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\conftest.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\conftest.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__init__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__init__.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_add_newdocs.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_add_newdocs.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_add_newdocs_scalars.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_add_newdocs_scalars.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_asarray.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_asarray.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_dtype.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_dtype.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_dtype_ctypes.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_dtype_ctypes.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_exceptions.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_exceptions.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_internal.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_internal.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_machar.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_machar.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_methods.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_methods.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_string_helpers.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_string_helpers.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_type_aliases.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_type_aliases.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\_ufunc_config.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\_ufunc_config.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\arrayprint.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\arrayprint.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\cversions.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\cversions.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\defchararray.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\defchararray.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\einsumfunc.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\einsumfunc.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\fromnumeric.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\fromnumeric.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\function_base.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\function_base.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\generate_numpy_api.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\generate_numpy_api.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\getlimits.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\getlimits.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\memmap.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\memmap.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\multiarray.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\multiarray.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\numeric.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\numeric.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\numerictypes.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\numerictypes.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\overrides.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\overrides.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\records.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\records.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\setup.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\setup.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\setup_common.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\setup_common.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\shape_base.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\shape_base.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\umath.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\umath.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\__pycache__\umath_tests.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\__pycache__\umath_tests.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_add_newdocs.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_add_newdocs.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_add_newdocs_scalars.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_add_newdocs_scalars.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_asarray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_asarray.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_asarray.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_asarray.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_dtype.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_dtype.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_dtype_ctypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_dtype_ctypes.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_exceptions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_exceptions.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_internal.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_internal.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_internal.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_internal.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_machar.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_machar.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_methods.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_methods.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_multiarray_tests.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_multiarray_tests.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_multiarray_umath.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_multiarray_umath.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_operand_flag_tests.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_operand_flag_tests.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_rational_tests.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_rational_tests.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_simd.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_simd.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_string_helpers.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_string_helpers.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_struct_ufunc_tests.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_struct_ufunc_tests.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_type_aliases.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_type_aliases.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_type_aliases.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_type_aliases.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_ufunc_config.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_ufunc_config.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_ufunc_config.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\_umath_tests.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\_umath_tests.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\arrayprint.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\arrayprint.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\arrayprint.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\arrayprint.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\cversions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\cversions.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\defchararray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\defchararray.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\defchararray.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\defchararray.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\einsumfunc.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\einsumfunc.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\einsumfunc.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\einsumfunc.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\fromnumeric.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\fromnumeric.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\fromnumeric.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\fromnumeric.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\function_base.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\function_base.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\function_base.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\function_base.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\generate_numpy_api.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\generate_numpy_api.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\getlimits.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\getlimits.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\getlimits.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\getlimits.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\include\numpy\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\core\include\~umpy
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\lib\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\core\~ib
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\memmap.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\memmap.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\memmap.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\memmap.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\multiarray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\multiarray.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\multiarray.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\multiarray.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\numeric.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\numeric.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\numeric.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\numeric.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\numerictypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\numerictypes.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\numerictypes.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\numerictypes.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\overrides.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\overrides.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\records.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\records.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\records.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\records.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\setup.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\setup.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\setup_common.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\setup_common.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\shape_base.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\shape_base.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\shape_base.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\shape_base.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\__init__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\core\tests\~_pycache__
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\_locales.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\_locales.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\data\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\core\tests\~ata
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\examples\cython\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\core\tests\examples\~ython
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\examples\limited_api\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\core\tests\examples\~imited_api
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test__exceptions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test__exceptions.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_abc.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_abc.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_api.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_api.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_argparse.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_argparse.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_array_coercion.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_array_coercion.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_array_interface.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_array_interface.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_arraymethod.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_arraymethod.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_arrayprint.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_arrayprint.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_casting_floatingpoint_errors.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_casting_floatingpoint_errors.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_casting_unittests.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_casting_unittests.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_conversion_utils.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_conversion_utils.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_cpu_dispatcher.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_cpu_dispatcher.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_cpu_features.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_cpu_features.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_custom_dtypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_custom_dtypes.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_cython.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_cython.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_datetime.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_datetime.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_defchararray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_defchararray.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_deprecations.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_deprecations.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_dlpack.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_dlpack.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_dtype.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_dtype.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_einsum.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_einsum.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_errstate.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_errstate.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_extint128.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_extint128.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_function_base.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_function_base.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_getlimits.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_getlimits.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_half.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_half.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_hashtable.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_hashtable.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_indexerrors.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_indexerrors.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_indexing.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_indexing.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_item_selection.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_item_selection.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_limited_api.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_limited_api.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_longdouble.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_longdouble.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_machar.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_machar.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_mem_overlap.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_mem_overlap.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_mem_policy.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_mem_policy.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_memmap.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_memmap.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_multiarray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_multiarray.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_nditer.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_nditer.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_nep50_promotions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_nep50_promotions.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_numeric.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_numeric.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_numerictypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_numerictypes.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_overrides.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_overrides.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_print.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_print.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_protocols.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_protocols.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_records.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_records.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_regression.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_regression.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_ctors.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_scalar_ctors.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_methods.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_scalar_methods.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarbuffer.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_scalarbuffer.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarinherit.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_scalarinherit.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarmath.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_scalarmath.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarprint.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_scalarprint.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_shape_base.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_shape_base.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_simd.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_simd.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_simd_module.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_simd_module.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_strings.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_strings.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_ufunc.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_ufunc.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_umath.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_umath.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_umath_accuracy.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_umath_accuracy.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_umath_complex.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_umath_complex.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\tests\test_unicode.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\tests\test_unicode.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\umath.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\umath.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\core\umath_tests.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\core\umath_tests.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\ctypeslib.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\ctypeslib.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\ctypeslib.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\ctypeslib.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\__config__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\__config__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\__init__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\__init__.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\__pycache__\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\distutils\~_pycache__
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\_shell_utils.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\_shell_utils.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\armccompiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\armccompiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\ccompiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\ccompiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\ccompiler_opt.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\ccompiler_opt.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\checks\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\distutils\~hecks
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\command\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\distutils\~ommand
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\conv_template.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\conv_template.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\core.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\core.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\cpuinfo.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\cpuinfo.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\exec_command.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\exec_command.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\extension.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\extension.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\fcompiler\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\distutils\~compiler
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\from_template.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\from_template.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\intelccompiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\intelccompiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\lib2def.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\lib2def.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\line_endings.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\line_endings.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\log.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\log.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\mingw32ccompiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\mingw32ccompiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\mingw\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\distutils\~ingw
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\misc_util.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\misc_util.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\msvc9compiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\msvc9compiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\msvccompiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\msvccompiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\npy_pkg_config.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\npy_pkg_config.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\numpy_distribution.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\numpy_distribution.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\pathccompiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\pathccompiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\setup.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\setup.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\system_info.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\system_info.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\tests\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\distutils\~ests
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\distutils\unixccompiler.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\distutils\unixccompiler.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\doc\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~oc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\dual.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\dual.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__init__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__init__.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__main__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__main__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\__main__.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\__main__.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\__version__.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\__version__.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\auxfuncs.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\auxfuncs.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\capi_maps.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\capi_maps.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\cb_rules.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\cb_rules.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\cfuncs.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\cfuncs.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\common_rules.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\common_rules.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\crackfortran.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\crackfortran.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\diagnose.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\diagnose.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\f2py2e.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\f2py2e.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\f90mod_rules.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\f90mod_rules.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\func2subr.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\func2subr.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\rules.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\rules.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\setup.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\setup.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\symbolic.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\symbolic.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__pycache__\use_rules.cpython-39.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__pycache__\use_rules.cpython-39.pyc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\__version__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\__version__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\auxfuncs.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\auxfuncs.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\capi_maps.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\capi_maps.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\cb_rules.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\cb_rules.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\cfuncs.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\cfuncs.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\common_rules.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\common_rules.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\crackfortran.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\crackfortran.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\diagnose.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\diagnose.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\f2py2e.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\f2py2e.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\f90mod_rules.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\f90mod_rules.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\func2subr.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\func2subr.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\rules.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\rules.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\setup.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\setup.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\src\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\f2py\~rc
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\symbolic.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\symbolic.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\tests\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\f2py\~ests
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\f2py\use_rules.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\f2py\use_rules.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\fft\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~ft
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\lib\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\~ib
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\license.txt
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\license.txt
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\linalg\__init__.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\linalg\__init__.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\__pycache__\
#    from C:\Users\HP\anaconda3\Lib\site-packages\numpy\linalg\~_pycache__
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\_umath_linalg.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\linalg\_umath_linalg.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\lapack_lite.cp39-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\linalg\lapack_lite.cp39-win_amd64.pyd
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\linalg.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\linalg\linalg.py
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\linalg.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\linalg\linalg.pyi
#   Moving to c:\users\hp\anaconda3\lib\site-packages\numpy\linalg\setup.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-gi4i98gv\linalg\setup.py
# ...
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\HP\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:266: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   creating build
#   creating build\src.win-amd64-3.9
#   creating build\src.win-amd64-3.9\numpy
#   creating build\src.win-amd64-3.9\numpy\distutils
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
#   error: subprocess-exited-with-error
#
#   python setup.py clean did not run successfully.
#   exit code: 1
#
#   [10 lines of output]
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for numpy
#   error: subprocess-exited-with-error
#
#   Running setup.py install for numpy did not run successfully.
#   exit code: 1
#
#   [280 lines of output]
#   Running from numpy source directory.
#
#   Note: if you need reliable uninstall behavior, then install
#   with pip instead of using `setup.py install`:
#
#     - `pip install .`       (from a git repo or downloaded source
#                              release)
#     - `pip install numpy`   (last NumPy release on PyPi)
#
#
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   C:\Users\HP\AppData\Local\Temp\pip-install-zu_ptcp4\numpy_3b066d150ac641f497d5d9a5607be5b1\numpy\distutils\system_info.py:639: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\HP\AppData\Local\Temp\pip-install-zu_ptcp4\numpy_3b066d150ac641f497d5d9a5607be5b1\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\HP\AppData\Local\Temp\pip-install-zu_ptcp4\numpy_3b066d150ac641f497d5d9a5607be5b1\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion' is not recognized as an internal or external command,
#   operable program or batch file.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\HP\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\HP\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\HP\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\HP\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\HP\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\HP\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\HP\\anaconda3\\lib', 'C:\\', 'C:\\Users\\HP\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\HP\AppData\Local\Temp\pip-install-zu_ptcp4\numpy_3b066d150ac641f497d5d9a5607be5b1\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\HP\AppData\Local\Temp\pip-install-zu_ptcp4\numpy_3b066d150ac641f497d5d9a5607be5b1\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\HP\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:266: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running install
#   C:\Users\HP\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !pip install autogluon --no-cache-dir

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.metrics import r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# ## AutoGluon Classifier

# %%
# Load in the wine dataset
wine = datasets.load_wine()

# %%
# Create the wine `data` dataset as a dataframe and name the columns with `feature_names`
df = pd.DataFrame(wine.data, columns=wine.feature_names)

# Include the target as well
df['target'] = wine.target

# %%
# Split your data with these ratios: train: 0.8 | test: 0.2
df_train, df_test = train_test_split(
    df,
    test_size=0.2,
    random_state=0
)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# No need to explicitly say this is a classifier, autogluon will pick it up
predictor = TabularPredictor(
    "time_limit": 120,
    "presets": "best_quality").fit(df_train[wine['feature_names']],df_train.target)

# %%
# Output the fit summary of the training run
predictor.summary()

# %%
# Evaluate the models performance on the test dataset
performance = predictor.evaluate(df_test)

# %% [markdown]
# ## AutoGluon Regression

# %%
# Load in the diabetes dataset
diabetes = datasets.load_diabetes()

# %%
# Create the diabetes `data` dataset as a dataframe and name the columns with `feature_names`
dfd = pd.DataFrame(diabetes.data, columns=diabetes['feature_names'])

# Include the target as well
dfd['target'] = diabetes.target

# %%
# Split your data with these ratios: train: 0.8 | test: 0.2
dfd_train, dfd_test = train_test_split(
    dfd,
    test_size=0.2,
    random_state=0
)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# No need to explicitly say this is a regression, autogluon will pick it up
predictor = TabularPredictor("eval_metric": r2
"time_limit": 120
"presets": "best_quality").fit(dfd_train[diabetes['feature_names']],dfd_t)

# %%
# Output the fit summary of the training run
?

# %%
# Evaluate the models performance on the test dataset
performance = ?
